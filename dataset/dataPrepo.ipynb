# %% [markdown]
# ## Data preprocessing

# %%
import os
import csv
import json
import sqlite3
import pandas as pd

def read_data_head(filepath):
  """
  Reads the head (first few lines) of a data file based on its extension.

  Args:
      filepath (str): Path to the data file.

  Prints the head of the file or an error message if the file type is unsupported.
  """
  extension = os.path.splitext(filepath)[1].lower()  # Get file extension
  try:
    if extension == '.csv':
      with open(filepath, 'r') as f:
        reader = csv.reader(f)
        print(f"Head of {filepath}:")
        for row in reader:
          print(row[:5])  # Print first 5 lines
          break  # Limit to 5 lines for head

    elif extension == '.json':
      with open(filepath, 'r') as f:
        data = json.load(f)
        print(f"Head of {filepath}:")
        print(data[:5])  # Print first 5 key-value pairs

    elif extension in ('.sql', '.sqlite'):
      conn = sqlite3.connect(filepath)
      cursor = conn.cursor()
      try:
        cursor.execute('SELECT * FROM (SELECT * FROM your_table LIMIT 5)')  # Replace 'your_table' with actual table name
      except sqlite3.OperationalError:  # Handle potential table name errors
        print(f"Error accessing table in {filepath}. Please check the table name.")
      else:
        print(f"Head of {filepath}:")
        for row in cursor:
          print(row)
      finally:
        conn.close()

    elif extension in ('.xls', '.xlsx'):
        try:
        # Replace 'your_engine' with the actual engine (e.g., 'openpyxl', 'xlrd')
            df = pd.read_excel(filepath, engine='your_engine')
            print(f"Head of {filepath}:")
            print(df.head(5))  # Print first 5 rows using pandas
        except Exception as e:
            print(f"Error reading {filepath}: {e}")
        
    else:
      print(f"Unsupported file type: {filepath}")
  except (FileNotFoundError, json.JSONDecodeError, pd.errors.ParserError) as e:
    print(f"Error reading {filepath}: {e}")

def main():
  """
  Iterates through files in the specified directory and calls read_data_head for each file,
  ignoring hidden files and directories.
  """
  data_dir = "/Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset"
  for filename in os.listdir(data_dir):
    if not filename.startswith('.') and os.path.isfile(os.path.join(data_dir, filename)):  # Ignore hidden files and directories
      read_data_head(os.path.join(data_dir, filename))

if __name__ == "__main__":
  main()
# Out:
# Error reading /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/EHR_List.xlsx: Unknown engine: your_engine
# Error reading /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/~$EHR_List.xlsx: Unknown engine: your_engine

# %%
import os
import csv

def read_csv_head(filepath):
  """
  Reads the head (first few lines) of a CSV file.

  Args:
      filepath (str): Path to the CSV file.

  Prints the head of the file or an error message if there's an issue.
  """
  if not filepath.endswith('.csv'):  # Check for CSV extension
    print(f"Skipping non-CSV file: {filepath}")
    return

  try:
    with open(filepath, 'r') as f:
      reader = csv.reader(f)
      print(f"Head of {filepath}:")
      for row in reader:
        print(row[:5])  # Print first 5 lines
        break  # Limit to 5 lines for head
  except FileNotFoundError:
    print(f"File not found: {filepath}")
  except Exception as e:  # Catch other potential errors
    print(f"Error reading {filepath}: {e}")

def explore_and_read_csv(folder_path):
  """
  Iterates through a folder and its subfolders, calling read_csv_head for each CSV file.

  Args:
      folder_path (str): Path to the folder containing CSV files.
  """
  for root, _, files in os.walk(folder_path):
    for filename in files:
      filepath = os.path.join(root, filename)
      read_csv_head(filepath)

if __name__ == "__main__":
  # Replace with the actual path to your folder containing CSV files
  folder_path = "/Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/"
  explore_and_read_csv(folder_path)
# Out:
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/.DS_Store
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/EHR_List.xlsx
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/~$EHR_List.xlsx
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/04 GH021.CMD2014.v1.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/.DS_Store
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/CODA_2013_v7_Anonymised.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/04 NG011.CMD2014.v1.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/04 NG021.CMD2017.v1.zip
# Head of /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/GH021.CMD2014.v1.csv:
# ['RecNr', 'CountryId', 'CentreId', 'IndividualId', 'Sex']
# Head of /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/CODA_2013_v7_Anonymised/CODA_2013_v7_Anonymised.csv:
# ['id\tsite\tyear\tagegp\tsex\tpy\tva_comp\tmal_level\thiv_level\tcause\twt\tlik\tlik_wt\tcausen\tsite_n\tcause_gp\tage_cat']
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Indepth Data/CODA_2013_v7_Anonymised/CODA_2013_v7_Anonymised.dta
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Predicting_Incident_HeartFailure_Disease_Based-on-Transformers/DataSets.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Predicting_Incident_HeartFailure_Disease_Based-on-Transformers/train_data.txt
# Head of /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Predicting_Incident_HeartFailure_Disease_Based-on-Transformers/heart.csv:
# ['\ufeffage', 'sex', 'cp', 'trestbps', 'chol']
# Head of /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/05 Exploratory Data Analysis(1).csv:
# ['INDICATOR', 'ISO3', 'YEAR', 'NumericValue']
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/42256_2020_180_MOESM3_ESM(1).zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/.DS_Store
# Head of /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/05 Exploratory Data Analysis.csv:
# ['INDICATOR', 'ISO3', 'YEAR', 'NumericValue']
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/train_catvnoncat.h5
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/patient_sequence
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/42256_2020_180_MOESM3_ESM.zip
# Head of /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/05 Exploratory Data Analysis(2).csv:
# ['INDICATOR', 'ISO3', 'YEAR', 'NumericValue']
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Demo-1.6.0.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/large-demo-data-1.9.7.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Demo-1.3.3-mysql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/demo-1.9.0.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Demo-1.2-mysql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/large-demo-data-2-2-1.sql.gz
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Demo-1.4.0.23-mysql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Demo-1.7.0.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/large-demo-data.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Demo-1.7.1.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/demo-1.11.0-update.sql.tar.gz
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/large-demo-data-1.11.9.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/openmrs-2-2-1.sql.gz
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/demo-2.0.1.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/demo-1.11.0.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/demo-1.12.0.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Demo-1.8.0.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/demo-1.10.0.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Openmrs-demo-sql-1.0.54.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/demo-1.11.0-alpha.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/Openmrs-demo-sql-1.1.0.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/downloadb47gV180422/large-demo-data-1.8.0.sql.zip
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/42256_2020_180_MOESM3_ESM/time_series_test_110_preprocess_en.xlsx
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Others/42256_2020_180_MOESM3_ESM/time_series_375_prerpocess_en.xlsx
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/bigbio/.DS_Store
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/bigbio/ehr_rel/.DS_Store
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/bigbio/ehr_rel/dataset_dict.json
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/bigbio/ehr_rel/train/state.json
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/bigbio/ehr_rel/train/dataset_info.json
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/bigbio/ehr_rel/train/data-00000-of-00001.arrow
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Medilora/.DS_Store
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Medilora/mimic_iii_diagnosis_anonymous/.DS_Store
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Medilora/mimic_iii_diagnosis_anonymous/dataset_dict.json
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Medilora/mimic_iii_diagnosis_anonymous/train/state.json
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Medilora/mimic_iii_diagnosis_anonymous/train/dataset_info.json
# Skipping non-CSV file: /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Medilora/mimic_iii_diagnosis_anonymous/train/data-00000-of-00001.arrow
# Head of /Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/MIMIC_EHR_Predictor/all_stays.csv:
# ['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'LAST_CAREUNIT', 'DBSOURCE']

# %%
import pandas as pd
data = pd.read_csv('/Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/MIMIC_EHR_Predictor/all_stays.csv')

data.head()
# Out:
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID LAST_CAREUNIT DBSOURCE  \
# 0         268   110404      280836          MICU  carevue
# 1         269   106296      206613          MICU  carevue
# 2         270   188028      220345           CCU  carevue
# 3         272   164716      210407           CCU  carevue
# 4         273   158689      241507          MICU  carevue
#
#                 INTIME              OUTTIME     LOS            ADMITTIME  \
# 0  2198-02-14 23:27:38  2198-02-18 05:26:11  3.2490  2198-02-11 13:40:00
# 1  2170-11-05 11:05:29  2170-11-08 17:46:57  3.2788  2170-11-05 11:04:00
# 2  2128-06-24 15:05:20  2128-06-27 12:32:29  2.8939  2128-06-23 18:26:00
# 3  2186-12-25 21:08:04  2186-12-27 12:01:13  1.6202  2186-12-25 21:06:00
# 4  2141-04-19 06:12:05  2141-04-20 17:52:11  1.4862  2141-04-19 06:11:00
#
#              DISCHTIME            DEATHTIME               ETHNICITY  \
# 0  2198-02-18 03:55:00  2198-02-18 03:55:00      HISPANIC OR LATINO
# 1  2170-11-27 18:00:00                  NaN                   WHITE
# 2  2128-06-27 12:31:00                  NaN   UNKNOWN/NOT SPECIFIED
# 3  2187-01-02 14:57:00                  NaN                   WHITE
# 4  2141-04-20 17:00:00                  NaN  BLACK/AFRICAN AMERICAN
#
#                                       DIAGNOSIS GENDER                  DOB  \
# 0                                       DYSPNEA      F  2132-02-21 00:00:00
# 1                      SEPSIS;PILONIDAL ABSCESS      M  2130-09-30 00:00:00
# 2  CAROTID STENOSIS\CAROTID ANGIOGRAM AND STENT      M  2048-05-26 00:00:00
# 3                             PULMONARY EMBOLIS      M  2119-11-21 00:00:00
# 4                        POLYSUBSTANCE OVERDOSE      M  2107-08-10 00:00:00
#
#                    DOD        AGE  MORTALITY_INUNIT  MORTALITY  \
# 0  2198-02-18 00:00:00  66.030075                 1          1
# 1                  NaN  40.127294                 0          0
# 2                  NaN  80.133229                 0          0
# 3                  NaN  67.142139                 0          0
# 4                  NaN  33.715776                 0          0
#
#    MORTALITY_INHOSPITAL
# 0                     1
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
# List of diagnoses to filter
diagnoses_to_keep = ['Malaria', 'Yellow Fever', 'Dengue', 'Smallpox', r'\bTB\b', 'Tuberculosis']

# Create a regex pattern that matches any of the diagnoses_to_keep
pattern = '|'.join(diagnoses_to_keep)

# Filter the DataFrame
filtered_data = data[data['DIAGNOSIS'].str.contains(pattern, case=False, na=False)]

filtered_data.head()
# Out:
#        SUBJECT_ID  HADM_ID  ICUSTAY_ID LAST_CAREUNIT DBSOURCE  \
# 2371         3677   152238      297060          MICU  carevue
# 6945        12119   181984      291377           CCU  carevue
# 8785        12071   167953      269116         TSICU  carevue
# 9936        12551   129696      265760          MICU  carevue
# 11679       14755   151669      235780          MICU  carevue
#
#                     INTIME              OUTTIME     LOS            ADMITTIME  \
# 2371   2106-10-25 13:10:55  2106-11-04 09:40:03  9.8536  2106-10-22 02:20:00
# 6945   2110-04-06 14:29:57  2110-04-09 13:26:59  2.9563  2110-04-05 20:03:00
# 8785   2127-04-15 17:26:00  2127-04-16 18:11:00  1.0313  2127-04-04 23:03:00
# 9936   2150-03-09 14:51:49  2150-03-10 14:49:02  0.9981  2150-03-05 16:46:00
# 11679  2125-02-09 18:35:05  2125-02-15 16:36:49  5.9179  2125-02-09 18:34:00
#
#                  DISCHTIME            DEATHTIME               ETHNICITY  \
# 2371   2106-11-04 09:40:00  2106-11-04 09:40:00  BLACK/AFRICAN AMERICAN
# 6945   2110-04-14 10:36:00                  NaN                   WHITE
# 8785   2127-04-18 18:33:00                  NaN  BLACK/AFRICAN AMERICAN
# 9936   2150-03-27 05:57:00  2150-03-27 05:57:00                   WHITE
# 11679  2125-02-23 16:30:00                  NaN                   WHITE
#
#                                                DIAGNOSIS GENDER  \
# 2371                                    PNEUMONIA-R/O TB      F
# 6945                       ABSCESS;RULE OUT TUBERCULOSIS      F
# 8785                                              R/O TB      M
# 9936   R/O TB-ADENOCARCINOMA-UNKNOWN PAIN-FEVER-R/O I...      F
# 11679  PNEUMONIA;HUMAN IMMUNODEFIENCY VIRUS;RULE OUT ...      F
#
#                        DOB                  DOD        AGE  MORTALITY_INUNIT  \
# 2371   2071-01-08 00:00:00  2106-11-04 00:00:00  35.817943                 1
# 6945   2072-03-06 00:00:00  2110-10-22 00:00:00  38.108504                 0
# 8785   2042-10-22 00:00:00  2127-06-12 00:00:00  84.536237                 0
# 9936   2103-04-25 00:00:00  2150-03-27 00:00:00  46.905806                 0
# 11679  2078-07-15 00:00:00                  NaN  46.604861                 0
#
#        MORTALITY  MORTALITY_INHOSPITAL
# 2371           1                     1
# 6945           0                     0
# 8785           0                     0
# 9936           1                     1
# 11679          0                     0

# %%
# Find columns with missing data
missing_data_columns = filtered_data.columns[filtered_data.isnull().any()].tolist()

# Display the columns with missing data
print("Columns with missing data:", missing_data_columns)
# Out:
# Columns with missing data: ['DEATHTIME', 'DOD']

# %%
# Write the DataFrame with missing data columns to a CSV file
filtered_data.to_csv('/Users/koissi/Desktop/HealtDataInsights/Diagnostic_Support_System/dataset/Filtered_data/MIMIC_EHR_Predictor_filtered_data.csv', index=False)

print("CSV file with missing data columns has been written.")
# Out:
# CSV file with missing data columns has been written.
